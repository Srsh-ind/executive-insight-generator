# %%
from analyzer import analyze_data

metrics = analyze_data("data/sample_sales_data.csv")

metrics
# Out:
# {'total_revenue': 1015000,
#  'growth': 37.5,
#  'top_region': 'NA',
#  'avg_churn': 5.25}

# %%
import pandas as pd
df = pd.read_csv("data/sample_sales_data.csv")
print(df.columns.tolist())
# Out:
# ['Date', ' Region', ' Revenue', ' Customers', ' Churn']

# %%
from analyzer import analyze_data

metrics = analyze_data("data/sample_sales_data.csv")

metrics
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
import pandas as pd

df = pd.read_csv("data/sample_sales_data.csv")

df.columns
# Out:
# Index(['Date', ' Region', ' Revenue', ' Customers', ' Churn'], dtype='object')

# %%
df.columns = df.columns.str.strip()

df.columns
# Out:
# Index(['Date', 'Region', 'Revenue', 'Customers', 'Churn'], dtype='object')

# %%
df.head()
# Out:
#       Date Region  Revenue  Customers  Churn
# 0  2023-01   APAC   120000        300      5
# 1  2023-02   APAC   140000        320      4
# 2  2023-01   EMEA    90000        250      6
# 3  2023-02   ΕΜΕΑ    95000        260      6
# 4  2023-03   ΕΜΕΑ   100000        270      7

# %%
df["Revenue"]
# Out:
# 0    120000
# 1    140000
# 2     90000
# 3     95000
# 4    100000
# 5    150000
# 6    155000
# 7    165000
# Name: Revenue, dtype: int64
